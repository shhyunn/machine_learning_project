# %%
# !pip install -U torchtext==0.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.4.0
#   Downloading torchtext-0.4.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.22.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.27.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (2.0.0+cu118)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.4.0) (1.26.15)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.12.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (3.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.4.0) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.4.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.4.0) (16.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.4.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
# Successfully installed torchtext-0.4.0

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.22.4)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %% [markdown]
# df마다 질문 토픽모델링->무슨 주제에 대한 데이터인지 알아놓기

# %%
import json
import pandas as pd

# jsonl 파일 불러오기
with open('/content/drive/MyDrive/딥러닝/open_qa.jsonl') as f:
    data = f.readlines()

# jsonl 데이터 파싱하여 Pandas DataFrame으로 변환
rows = []
for d in data:
    row = json.loads(d)
    rows.append({'question': row['question'], 'human_answers': ', '.join(row['human_answers']), 'chatgpt_answers': ', '.join(row['chatgpt_answers'])})
df1 = pd.DataFrame(rows)

# %%
df1
# Out:
#                                                question  \
# 0                         what composer used sound mass
# 1                  where did the persian war take place
# 2                                      what are add ons
# 3                               how does a dredge work?
# 4                what classes are considered humanities
# ...                                                 ...
# 1182                           when did secretariat win
# 1183                          what is a full job time??
# 1184  what are the three primary colors in the subtr...
# 1185                  what are layers of the ionosphere
# 1186                       what state is new orleans in
#
#                                           human_answers  \
# 0     Composers and works include Barbara Kolb , Pau...
# 1     The Greco-Persian Wars (also often called the ...
# 2     Plug-in (computing) , a piece of software whic...
# 3     Dredging is an excavation activity or operatio...
# 4     The humanities are academic disciplines that s...
# ...                                                 ...
# 1182  Secretariat (March 30, 1970 – October 4, 1989)...
# 1183  Full-time employment is employment in which a ...
# 1184  The overlapping subtractive yellow, cyan and r...
# 1185  The ionosphere is a region of the upper atmosp...
# 1186  New Orleans ( or , locally or ; ) is a major U...
#
#                                         chatgpt_answers
# 0     Sound mass is a term used to describe a type o...
# 1     The Persian Wars were a series of conflicts fo...
# 2     Add-ons, also known as extensions or plug-ins,...
# 3     A dredge is a piece of equipment that is used ...
# 4     Humanities are academic disciplines that study...
# ...                                                 ...
# 1182  Secretariat was an American Thoroughbred raceh...
# 1183  A full-time job typically refers to a job that...
# 1184  The three primary colors in the subtractive co...
# 1185  The ionosphere is a region of Earth's upper at...
# 1186  New Orleans is a city located in the state of ...
#
# [1187 rows x 3 columns]

# %%
df1['human_answers'][0]
# Out:
# 'Composers and works include Barbara Kolb , Pauline Oliveros \' Sound Patterns for chorus (1961), Norma Beecroft \'s From Dreams of Brass for chorus (1963–1964), and Nancy Van de Vate .A very early example is the opening of Jean-Féry Rebel \'s ballet Les Elémens (1737–38), where chaos is represented by a gradually cumulating orchestral cluster of all seven notes of the D minor scale (Henck 2004, pp. 52–54).A later example is the third movement of Ruth Crawford Seeger \'s String Quartet 1931 (Nonesuch H-71280) while more recently Phill Niblock \'s multiple drone based music serves as an example.The use of "chords approaching timbres" begins with Debussy and Edgard Varèse often carefully scored individual instrumental parts so that they would fuse into one ensemble timbre or sound mass (Erickson 1975, pp. 18 and 21).Other examples include European "textural" compositions of the fifties and sixties such as Krzysztof Penderecki \'s Threnody to the Victims of Hiroshima (1959) and György Ligeti \'s works featuring micropolyphony in works like Atmosphères (1961) and his Requiem (1963-65).Other composers with works using this technique include Henryk Górecki , Karel Husa , Witold Lutosławski , Kazimierz Serocki , and Steven Stucky .Sound mass techniques also appear in the music of George Crumb (Anon. n.d.).'

# %%
import json
import pandas as pd

# jsonl 파일 불러오기
with open('/content/drive/MyDrive/딥러닝/finance.jsonl') as f:
    data = f.readlines()

# jsonl 데이터 파싱하여 Pandas DataFrame으로 변환
rows = []
for d in data:
    row = json.loads(d)
    rows.append({'question': row['question'], 'human_answers': ', '.join(row['human_answers']), 'chatgpt_answers': ', '.join(row['chatgpt_answers'])})
df2 = pd.DataFrame(rows)

# %%
df2
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 3928  Challenged an apparently bogus credit card cha...
# 3929  Does a stay at home mom need term life insurance?
# 3930             Rules for SEP contributions in an LLC?
# 3931  How do credit card payments work? What ensures...
# 3932                               Beginning investment
#
#                                           human_answers  \
# 0     There is most likely an error in the WSJ's dat...
# 1     I know this question has a lot of answers alre...
# 2     If you pay it off before the cycle closes it w...
# 3     It is the first time I encounter redemption pr...
# 4     Why Investors Buy Platinum is an old (1995) ar...
# ...                                                 ...
# 3928  Yes.  For $15 it's not worth anyone's time to ...
# 3929  Another source of insurance can be through the...
# 3930  From Schwab -  What are the eligibility requir...
# 3931  Your credit card limit is nothing more than a ...
# 3932  I am a huge fan of jim Cramer and while you ma...
#
#                                         chatgpt_answers
# 0     Historical price-to-earnings (P/E) ratios for ...
# 1     Co-signing a personal loan for a friend or fam...
# 2     It can be a good idea to avoid using credit ca...
# 3     Share split and redemption are two different c...
# 4     Gold and platinum are both precious metals tha...
# ...                                                 ...
# 3928  If you have challenged a credit card charge th...
# 3929  It is generally a good idea for stay-at-home m...
# 3930  A SEP (Simplified Employee Pension) is a type ...
# 3931  When you make a purchase with a credit card, t...
# 3932  If you're interested in beginning your investm...
#
# [3933 rows x 3 columns]

# %%
import json
import pandas as pd

# jsonl 파일 불러오기
with open('/content/drive/MyDrive/딥러닝/medicine.jsonl') as f:
    data = f.readlines()

# jsonl 데이터 파싱하여 Pandas DataFrame으로 변환
rows = []
for d in data:
    row = json.loads(d)
    rows.append({'question': row['question'], 'human_answers': ', '.join(row['human_answers']), 'chatgpt_answers': ', '.join(row['chatgpt_answers'])})
df3 = pd.DataFrame(rows)

# %%
df3
# Out:
#                                                question  \
# 0     Does Primolut N taken during pregnancy affect ...
# 1     Bloating and pain on right lower abdomen. Shou...
# 2     Is chest pain related to intake of clindamycin...
# 3     Q. Noticed a yellowish sag in the gums of my 1...
# 4     Suggest remedy for low grade fever, hot and co...
# ...                                                 ...
# 1243  Is rise in pressure from 116/66 to 140/80 norm...
# 1244  What could cause a painless lump in the right ...
# 1245  Can Acutret be given to a child for treatment ...
# 1246  Are BP of 119/65 and pulse of 35 causes for co...
# 1247  Suggest treatment for back pain after walking ...
#
#                                           human_answers  \
# 0     Hi,     Thanks for the query. I understand you...
# 1     Hello,Thanks for the query to H.C.M. Forum.Pai...
# 2     Hello, The use of Clindamycin can cause stomac...
# 3     Hello. Revert back with the photos to a dentis...
# 4     Hi Dear,Welcome to Healthcaremagic Team.Unders...
# ...                                                 ...
# 1243  Hello!Welcome and thank you for asking on HCM!...
# 1244  Hi, * As per my surgical experience, the issue...
# 1245  Although it is difficult to comment whether Ac...
# 1246  Welcome and thank you for asking on HCM! I hav...
# 1247  Hi,Having this type of back pain at this age i...
#
#                                         chatgpt_answers
# 0     It is not recommended to use Primolut N during...
# 1     If you are experiencing abdominal pain and blo...
# 2     It is possible that chest pain could be relate...
# 3     It is difficult to accurately diagnose a condi...
# 4     I'm sorry to hear that you're feeling sick. It...
# ...                                                 ...
# 1243  It's not uncommon for blood pressure to fluctu...
# 1244  There are several possible causes of a painles...
# 1245  It is not appropriate for me to recommend a sp...
# 1246  It is not uncommon for people with rheumatoid ...
# 1247  It is not uncommon to experience back pain, es...
#
# [1248 rows x 3 columns]

# %%
import json
import pandas as pd

# jsonl 파일 불러오기
with open('/content/drive/MyDrive/딥러닝/reddit_eli5.jsonl') as f:
    data = f.readlines()

# jsonl 데이터 파싱하여 Pandas DataFrame으로 변환
rows = []
for d in data:
    row = json.loads(d)
    rows.append({'question': row['question'], 'human_answers': ', '.join(row['human_answers']), 'chatgpt_answers': ', '.join(row['chatgpt_answers'])})
df4 = pd.DataFrame(rows)

# %%
df4
# Out:
#                                                 question  \
# 0      Why is every book I hear about a " NY Times # ...
# 1      If salt is so bad for cars , why do we use it ...
# 2      Why do we still have SD TV channels when HD lo...
# 3      Why has nobody assassinated Kim Jong - un He i...
# 4      How was airplane technology able to advance so...
# ...                                                  ...
# 17107  Why is the general Xbox One reveal feedback ne...
# 17108  If infrared is thermal why does n't my remote ...
# 17109  Why are cars all about their brake - horse pow...
# 17110  What does a CO^2 scrubber do , and how does it...
# 17111  the Stockholm riots happening right now Why ar...
#
#                                            human_answers  \
# 0      Basically there are many categories of " Best ...
# 1      salt is good for not dying in car crashes and ...
# 2      The way it works is that old TV stations got a...
# 3      You ca n't just go around assassinating the le...
# 4      Wanting to kill the shit out of Germans drives...
# ...                                                  ...
# 17107  A few items people do n't seem to like : 1 . G...
# 17108  It 's very , very low power . Around the order...
# 17109  Brake horsepower has nothing to do with brakes...
# 17110  A [ scrubber ] ( URL_0 ) is a engineering proc...
# 17111  I feel like I just failed the Swede test , bec...
#
#                                          chatgpt_answers
# 0      There are many different best seller lists tha...
# 1      Salt is used on roads to help melt ice and sno...
# 2      There are a few reasons why we still have SD (...
# 3      It is generally not acceptable or ethical to a...
# 4      After the Wright Brothers made the first power...
# ...                                                  ...
# 17107  It's difficult to say exactly why the general ...
# 17108  Infrared light is a type of light that we can'...
# 17109  Cars are not just about how fast they can go, ...
# 17110  A CO2 scrubber is a device that removes carbon...
# 17111  I'm sorry, but I'm not able to provide informa...
#
# [17112 rows x 3 columns]

# %%
import json
import pandas as pd

# jsonl 파일 불러오기
with open('/content/drive/MyDrive/딥러닝/wiki_csai.jsonl') as f:
    data = f.readlines()

# jsonl 데이터 파싱하여 Pandas DataFrame으로 변환
rows = []
for d in data:
    row = json.loads(d)
    rows.append({'question': row['question'], 'human_answers': ', '.join(row['human_answers']), 'chatgpt_answers': ', '.join(row['chatgpt_answers'])})
df5 = pd.DataFrame(rows)

# %%
df5
# Out:
#                                               question  \
# 0            Please explain what is "Animal cognition"
# 1          Please explain what is "Human intelligence"
# 2    Please explain what is "Oxford English Diction...
# 3     Please explain what is "Oxford University Press"
# 4             Please explain what is "AI applications"
# ..                                                 ...
# 837             Please explain what is "Punched cards"
# 838                Please explain what is "Paper tape"
# 839               Please explain what is "BBC Model B"
# 840                   Please explain what is "O level"
# 841                   Please explain what is "A level"
#
#                                          human_answers  \
# 0    Animal cognition encompasses the mental capaci...
# 1    Human intelligence is the intellectual capabil...
# 2    The Oxford English Dictionary (OED) is the fir...
# 3    Oxford University Press (OUP) is the universit...
# 4    Artificial intelligence (AI) has been used in ...
# ..                                                 ...
# 837  A punched card (also punch card or punched-car...
# 838  Punched tape or perforated paper tape is a for...
# 839  The British Broadcasting Corporation Microcomp...
# 840  The O-Level (Ordinary Level) is a subject-base...
# 841  The A-Level (Advanced Level) is a subject-base...
#
#                                        chatgpt_answers
# 0    Animal cognition refers to the mental capaciti...
# 1    Human intelligence is the mental ability to th...
# 2    The Oxford English Dictionary (OED) is a compr...
# 3    Oxford University Press (OUP) is a department ...
# 4    AI applications are computer systems that are ...
# ..                                                 ...
# 837  Punched cards were a means of storing and proc...
# 838  Paper tape is a medium for storing and transmi...
# 839  The BBC Model B is a computer that was made by...
# 840  "O level" refers to the General Certificate of...
# 841  A level, or Advanced level, is a qualification...
#
# [842 rows x 3 columns]

# %%
import nltk
nltk.download('names')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import names
all_names = set(names.words())
from nltk.corpus import stopwords
stopwords = set(stopwords.words())

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
#1. LDA 토픽모델링
#series list로 만들기
df1_question = df1['question'].to_list()
df2_question = df2['question'].to_list()
df3_question = df3['question'].to_list()
df4_question = df4['question'].to_list()
df5_question = df5['question'].to_list()
#question 리스트만 딕셔너리로 저장
question_dic = {'df1':df1_question, 'df2':df2_question, 'df3':df3_question, 'df4':df4_question, 'df5':df5_question}

# %%
def make_word(doc): #토픽모델링을 위한 전처리 함수
  cleaned_doc = []
  for word in doc.split(' '):
    word = word.lower()
    if word.isalpha() and word not in all_names and word not in stopwords and len(word) > 2: #알파벳이고 고유명사가 아니며 불용어가 아니고 2단어 이상인 경우
      cleaned_doc.append(lemmatizer.lemmatize(word))
  return cleaned_doc

word_dic = {}
for df in ['df1','df2','df3','df4','df5']:
  temps = [make_word(doc) for doc in question_dic[df]]
  word_dic[df] = temps

# %%
import matplotlib.pyplot as plt
from gensim.models import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora import Dictionary

for df in ['df1','df2','df3','df4','df5']:
  docs = word_dic[df]
  dictionary = Dictionary(docs)
  corpus = [dictionary.doc2bow(doc) for doc in docs]
  # 최적의 토픽 개수 찾기 5-15개까지 perplexity, coherence 계산
  start_topic_count = 5
  end_topic_count = 15
  perplexity_scores = []
  coherence_scores = []
  for i in range(start_topic_count, end_topic_count+1):
    model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=i, passes=10)
    perplexity = model.log_perplexity(corpus)
    perplexity_scores.append(perplexity)
    coherence_model_lda = CoherenceModel(model=model, texts=docs, dictionary=dictionary, coherence='c_v')
    coherence = coherence_model_lda.get_coherence()
    coherence_scores.append(coherence)
    print("토픽 개수: {}, Perplexity: {}, Coherence Score: {}".format(i, perplexity, coherence))

  # 결과를 시각화합니다.
  x = range(start_topic_count, end_topic_count+1)
  fig, ax1 = plt.subplots()
  ax1.plot(x, perplexity_scores, 'b-')
  ax1.set_xlabel('Topic Counts')
  ax1.set_ylabel('Perplexity', color='b')
  ax2 = ax1.twinx()
  ax2.plot(x, coherence_scores, 'r-')
  ax2.set_ylabel('Coherence Score', color='r')
  plt.show()
# Out:
# 토픽 개수: 5, Perplexity: -8.4388841174863, Coherence Score: 0.7565973145962095
# 토픽 개수: 6, Perplexity: -8.51425223542585, Coherence Score: 0.747697694099426
# 토픽 개수: 7, Perplexity: -8.627247180932233, Coherence Score: 0.748002199499603
# 토픽 개수: 8, Perplexity: -8.674160424366688, Coherence Score: 0.742545414437443
# 토픽 개수: 9, Perplexity: -8.73351123301262, Coherence Score: 0.7446517034169586
# 토픽 개수: 10, Perplexity: -8.786480155749999, Coherence Score: 0.7301737496403986
# 토픽 개수: 11, Perplexity: -8.831772828697556, Coherence Score: 0.7307072999596232
# 토픽 개수: 12, Perplexity: -8.879689486338775, Coherence Score: 0.7273486106327655
# 토픽 개수: 13, Perplexity: -8.916989959090978, Coherence Score: 0.724713294667183
# 토픽 개수: 14, Perplexity: -8.95431444698802, Coherence Score: 0.7115380968301627
# 토픽 개수: 15, Perplexity: -9.012672798684514, Coherence Score: 0.6985217222268609
# 토픽 개수: 5, Perplexity: -7.444200789341764, Coherence Score: 0.3955332685362825
# 토픽 개수: 6, Perplexity: -7.4920459917992295, Coherence Score: 0.40627172784084203
# 토픽 개수: 7, Perplexity: -7.521104141157068, Coherence Score: 0.41258588169871785
# 토픽 개수: 8, Perplexity: -7.56042853386646, Coherence Score: 0.41366436678326035
# 토픽 개수: 9, Perplexity: -7.586824223454937, Coherence Score: 0.4237834611495583
# 토픽 개수: 10, Perplexity: -7.58463154272608, Coherence Score: 0.43550473316450866
# 토픽 개수: 11, Perplexity: -7.628211473697199, Coherence Score: 0.4636302853365613
# 토픽 개수: 12, Perplexity: -7.652204361518087, Coherence Score: 0.48125900474967515
# 토픽 개수: 13, Perplexity: -7.919779938765925, Coherence Score: 0.505504207146159
# 토픽 개수: 14, Perplexity: -8.426405948797509, Coherence Score: 0.5057454325366366
# 토픽 개수: 15, Perplexity: -8.577217825482872, Coherence Score: 0.5231442818103251
# 토픽 개수: 5, Perplexity: -7.795681365082044, Coherence Score: 0.24157393566778426
# 토픽 개수: 6, Perplexity: -7.816160561971834, Coherence Score: 0.2587634597495694
# 토픽 개수: 7, Perplexity: -7.850856740418949, Coherence Score: 0.23704042012522
# 토픽 개수: 8, Perplexity: -7.86990053925346, Coherence Score: 0.25802767878908744
# 토픽 개수: 9, Perplexity: -7.88182327089249, Coherence Score: 0.25727672437199006
# 토픽 개수: 10, Perplexity: -7.892677404141578, Coherence Score: 0.24900067333212808
# 토픽 개수: 11, Perplexity: -7.893952514124239, Coherence Score: 0.28305744925090687
# 토픽 개수: 12, Perplexity: -7.929251788451462, Coherence Score: 0.25967688634200004
# 토픽 개수: 13, Perplexity: -7.9549623113044525, Coherence Score: 0.25943707525519216
# 토픽 개수: 14, Perplexity: -8.003074745738484, Coherence Score: 0.2685858574848251
# 토픽 개수: 15, Perplexity: -7.99343428184493, Coherence Score: 0.2535666995742993
# 토픽 개수: 5, Perplexity: -8.196395909536152, Coherence Score: 0.22396717925788953
# 토픽 개수: 6, Perplexity: -8.222231235564303, Coherence Score: 0.25388603314729946
# 토픽 개수: 7, Perplexity: -8.23499380735355, Coherence Score: 0.2740664498803982
# 토픽 개수: 8, Perplexity: -8.325252004654292, Coherence Score: 0.29296528640550945
# 토픽 개수: 9, Perplexity: -8.470483318367258, Coherence Score: 0.28971552430647446
# 토픽 개수: 10, Perplexity: -8.653240895048441, Coherence Score: 0.3073443045032073
# 토픽 개수: 11, Perplexity: -8.961123962594126, Coherence Score: 0.32818338193078134
# 토픽 개수: 12, Perplexity: -9.468713940142228, Coherence Score: 0.3520437531924494
# 토픽 개수: 13, Perplexity: -9.91217170561471, Coherence Score: 0.3110452748919004
# 토픽 개수: 14, Perplexity: -10.193990596829932, Coherence Score: 0.31010950239153157
# 토픽 개수: 15, Perplexity: -10.367872300050081, Coherence Score: 0.3421461883894063
# 토픽 개수: 5, Perplexity: -2.592039243957733, Coherence Score: 0.7567525122770767
# 토픽 개수: 6, Perplexity: -2.7257971736210003, Coherence Score: 0.7581367377056893
# 토픽 개수: 7, Perplexity: -2.859007516506373, Coherence Score: 0.7588554348501937
# 토픽 개수: 8, Perplexity: -3.0080294489939288, Coherence Score: 0.7662211440618603
# 토픽 개수: 9, Perplexity: -3.113149546210733, Coherence Score: 0.7662755624919392
# 토픽 개수: 10, Perplexity: -3.2297905989545908, Coherence Score: 0.7678649839144065
# 토픽 개수: 11, Perplexity: -3.2924570175565275, Coherence Score: 0.7705805396926021
# 토픽 개수: 12, Perplexity: -3.3074703156417677, Coherence Score: 0.7688803756614658
# 토픽 개수: 13, Perplexity: -3.4607239138524464, Coherence Score: 0.7695465658152626
# 토픽 개수: 14, Perplexity: -3.4616582769350948, Coherence Score: 0.768574530883282
# 토픽 개수: 15, Perplexity: -3.491648955801078, Coherence Score: 0.7614270401322715

# %%
#최적의 토픽 개수
num_topic = {'df1':14,'df2':5,'df3':7,'df4':12,'df5':7}

# %%
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel

for df in ['df1','df2','df3','df4','df5']:
  docs = word_dic[df]
  dictionary = Dictionary(docs)

  corpus = [dictionary.doc2bow(doc) for doc in docs]

  # LDA 모델 학습
  lda_model = LdaModel(corpus, num_topics=num_topic[df], id2word=dictionary, passes=10)
  print(f"{df}의 토픽모델링 결과 입니다.")
  # 각 토픽의 단어 분포 출력
  topics = lda_model.show_topics(num_topics=num_topic[df], num_words=7, formatted=False)
  for topic in topics:
    print(topic)
# Out:
# df1의 토픽모델링 결과 입니다.
# (0, [('play', 0.014828433), ('kind', 0.012283763), ('player', 0.009943722), ('harbor', 0.009922094), ('pearl', 0.009922085), ('book', 0.009921979), ('school', 0.009281345)])
# (1, [('year', 0.017937733), ('code', 0.015261526), ('area', 0.012867326), ('john', 0.012588247), ('make', 0.010361874), ('kennedy', 0.010221275), ('song', 0.007833868)])
# (2, [('president', 0.02389437), ('county', 0.012648398), ('color', 0.009541771), ('plant', 0.009541745), ('primary', 0.009476575), ('deep', 0.006435079), ('foot', 0.0064350776)])
# (3, [('state', 0.048603237), ('city', 0.014242216), ('born', 0.011453848), ('day', 0.008674547), ('university', 0.008615634), ('medicine', 0.008556578), ('played', 0.0058273165)])
# (4, [('located', 0.014941458), ('county', 0.009197193), ('great', 0.009176622), ('nixon', 0.0062206476), ('richard', 0.0062206336), ('texas', 0.0062206318), ('ford', 0.0062206304)])
# (5, [('world', 0.022828514), ('kind', 0.017236985), ('cup', 0.017068936), ('system', 0.011479664), ('work', 0.011479657), ('part', 0.011443459), ('president', 0.008719063)])
# (6, [('super', 0.017510375), ('type', 0.014647718), ('bowl', 0.011733804), ('released', 0.008845467), ('year', 0.0060083037), ('movie', 0.0059827613), ('north', 0.0059827575)])
# (7, [('year', 0.017767131), ('wrote', 0.017659623), ('song', 0.011931751), ('begin', 0.0090010995), ('girl', 0.009001068), ('planet', 0.008975141), ('lipoic', 0.0060704583)])
# (8, [('made', 0.06562347), ('state', 0.022565635), ('season', 0.016541636), ('law', 0.0090230275), ('year', 0.007749268), ('united', 0.007717696), ('political', 0.0052261883)])
# (9, [('group', 0.019392967), ('language', 0.009851897), ('file', 0.009823481), ('sign', 0.009823469), ('committee', 0.0066442727), ('banana', 0.0066442667), ('definition', 0.0066442564)])
# (10, [('day', 0.02356365), ('country', 0.015356842), ('luther', 0.012299265), ('martin', 0.012299255), ('rose', 0.009300559), ('king', 0.009269587), ('world', 0.006285887)])
# (11, [('world', 0.014855859), ('play', 0.013889552), ('country', 0.01112648), ('mexico', 0.008387656), ('part', 0.005673082), ('jackson', 0.005673077), ('american', 0.0056730644)])
# (12, [('live', 0.026918316), ('bible', 0.0202991), ('american', 0.010306639), ('water', 0.010306614), ('disease', 0.010306602), ('function', 0.0102471225), ('side', 0.0069509163)])
# (13, [('county', 0.03184848), ('country', 0.014255098), ('human', 0.011424248), ('washington', 0.011374525), ('stand', 0.011340413), ('played', 0.005812262), ('game', 0.00581226)])
# df2의 토픽모델링 결과 입니다.
# (0, [('stock', 0.029661937), ('make', 0.019745005), ('car', 0.017997192), ('rate', 0.017860446), ('find', 0.0166627), ('interest', 0.016074078), ('fund', 0.01303193)])
# (1, [('stock', 0.047865715), ('company', 0.043326065), ('buy', 0.027044965), ('share', 0.0167048), ('price', 0.016462075), ('market', 0.013304212), ('money', 0.013157935)])
# (2, [('credit', 0.051612206), ('card', 0.02724771), ('pay', 0.025548616), ('finance', 0.021677494), ('tax', 0.019532353), ('personal', 0.017584052), ('capital', 0.01364306)])
# (3, [('tax', 0.03154393), ('account', 0.016588701), ('cash', 0.015976349), ('return', 0.015815228), ('stock', 0.01310925), ('bank', 0.011784409), ('fund', 0.0114078)])
# (4, [('investment', 0.03163834), ('mortgage', 0.018805273), ('invest', 0.015294461), ('market', 0.0142811965), ('loan', 0.013735079), ('year', 0.0134037165), ('term', 0.009494462)])
# df3의 토픽모델링 결과 입니다.
# (0, [('month', 0.013924182), ('day', 0.013916068), ('year', 0.010177446), ('suggest', 0.008931444), ('taking', 0.008418188), ('fever', 0.007686748), ('pain', 0.0072653797)])
# (1, [('pain', 0.032941446), ('day', 0.011877378), ('year', 0.010429557), ('lump', 0.010043168), ('treatment', 0.0095192585), ('suggest', 0.008396865), ('month', 0.0071872617)])
# (2, [('year', 0.01681335), ('week', 0.011065861), ('suggest', 0.009287595), ('day', 0.008502331), ('treatment', 0.007868273), ('feel', 0.007743863), ('doctor', 0.007067701)])
# (3, [('pain', 0.02868876), ('blood', 0.01661099), ('left', 0.014033953), ('doctor', 0.011937037), ('year', 0.008396489), ('time', 0.007989687), ('upper', 0.0078113494)])
# (4, [('pain', 0.030993454), ('day', 0.010952762), ('feel', 0.00981436), ('back', 0.009594677), ('suggest', 0.0090707), ('treatment', 0.008194669), ('period', 0.0078328755)])
# (5, [('year', 0.01984352), ('pain', 0.01797894), ('back', 0.011075296), ('suggest', 0.009722496), ('lower', 0.008299744), ('hair', 0.0076714023), ('time', 0.0058007347)])
# (6, [('side', 0.01162834), ('left', 0.011123018), ('doctor', 0.008890916), ('suggest', 0.008556619), ('treatment', 0.00811886), ('month', 0.0081061), ('feel', 0.008026901)])
# df4의 토픽모델링 결과 입니다.
# (0, [('explain', 0.09681021), ('car', 0.039572775), ('child', 0.010659308), ('engine', 0.010491803), ('hot', 0.009739814), ('male', 0.008667925), ('system', 0.008564365)])
# (1, [('explain', 0.047873534), ('life', 0.039556723), ('illegal', 0.024142178), ('hair', 0.02061334), ('cost', 0.02044803), ('zero', 0.014719725), ('cancer', 0.014215656)])
# (2, [('explain', 0.09348445), ('body', 0.021657549), ('feel', 0.020198602), ('person', 0.016226737), ('cold', 0.013491016), ('hand', 0.013307009), ('cut', 0.013274138)])
# (3, [('explain', 0.076179), ('computer', 0.038559463), ('game', 0.030829055), ('light', 0.018119533), ('work', 0.014427512), ('website', 0.011175263), ('drive', 0.010410527)])
# (4, [('water', 0.0854413), ('explain', 0.048689004), ('food', 0.047416996), ('taste', 0.025784597), ('eat', 0.022709008), ('drink', 0.0201836), ('dog', 0.018710354)])
# (5, [('explain', 0.099688254), ('money', 0.028295308), ('make', 0.021008339), ('company', 0.014999605), ('work', 0.010702659), ('understand', 0.010115978), ('tax', 0.009190866)])
# (6, [('explain', 0.052057046), ('purpose', 0.025290985), ('file', 0.023073597), ('bit', 0.019783078), ('science', 0.01803658), ('camera', 0.015175956), ('glass', 0.014597298)])
# (7, [('explain', 0.1056079), ('make', 0.00972898), ('color', 0.008664907), ('reason', 0.007113616), ('hate', 0.0070889667), ('expensive', 0.0065143523), ('alcohol', 0.0064177373)])
# (8, [('explain', 0.07921718), ('country', 0.043692537), ('american', 0.024681505), ('state', 0.022302542), ('law', 0.017378462), ('government', 0.0147514045), ('america', 0.014442868)])
# (9, [('explain', 0.12469755), ('time', 0.018471159), ('work', 0.012422183), ('movie', 0.010788937), ('understand', 0.0096657695), ('internet', 0.008505275), ('make', 0.0076928833)])
# (10, [('explain', 0.10543916), ('year', 0.0129832085), ('make', 0.012017434), ('brain', 0.011460362), ('human', 0.011261203), ('smell', 0.01123824), ('sleep', 0.00964395)])
# (11, [('explain', 0.10155289), ('difference', 0.042080782), ('language', 0.022767236), ('different', 0.01875218), ('edit', 0.0154997), ('understand', 0.01256086), ('type', 0.011334791)])
# df5의 토픽모델링 결과 입니다.
# (0, [('lifetime', 0.065505154), ('explain', 0.009132112), ('image', 0.008189945), ('density', 0.008189741), ('language', 0.008189725), ('processing', 0.0081897145), ('learning', 0.008189684)])
# (1, [('explain', 0.3581193), ('artificial', 0.09359852), ('data', 0.07507702), ('intelligence', 0.020799458), ('mark', 0.020799445), ('autonomous', 0.020799443), ('network', 0.020799413)])
# (2, [('explain', 0.37107274), ('machine', 0.06776385), ('game', 0.018773492), ('usage', 0.01877348), ('university', 0.018773478), ('search', 0.018773476), ('butler', 0.018773472)])
# (3, [('explain', 0.39365846), ('neural', 0.07549754), ('grounding', 0.016776968), ('benedikt', 0.016776957), ('answering', 0.016776957), ('catastrophic', 0.016776953), ('traffic', 0.016776942)])
# (4, [('explain', 0.91772246), ('language', 0.0051406953), ('processing', 0.005140693), ('image', 0.0051406813), ('generation', 0.0026588545), ('brain', 0.0026588447), ('learning', 0.0026588384)])
# (5, [('explain', 0.38578945), ('component', 0.061383072), ('control', 0.04676594), ('reinforcement', 0.031754088), ('xavier', 0.017005619), ('neighbor', 0.017005594), ('operating', 0.017005583)])
# (6, [('explain', 0.25463548), ('computer', 0.09598227), ('markov', 0.06554098), ('hash', 0.03509983), ('positive', 0.03509981), ('ontology', 0.035099763), ('machine', 0.004660207)])

# %% [markdown]
# df1: 스포츠와 관련된 question
# df2: 투자, 주식과 관련된 question
# df3: 건강과 관련된 question
# df4:다양한 주제들에 대해 설명을 요구하는 question (인생, 컴퓨터, 음식, 나라, 정부)
# df5:다양한 주제들에 관해 설명을 요구하는 question (이미지, 언어, 컴퓨터, 기계학습)
# -> 전체의 성능 vs 분야별 성능을 비교 -> chatgpt와 human의 텍스트가 더욱 효과적으로 구분되는 분야를 알아보기로 결정,
# 분야별 성능은 설명을 요구하는 question vs 그렇지 않은 question, df1,2,3과 df 4,5를 구분지어 모델의 성능 비교

# %%
import numpy as np
#각각의 라벨의 데이터프레임의 행 길이만큼의 라벨 shape 생성, y데이터 저장
#human answer과 chatgpt answer로 나눠서 데이터프레임 저장
df1_human_y = np.full((df1.shape[0],),0)
df1_chatgpt_y = np.full((df1.shape[0],),1)

df2_human_y = np.full((df2.shape[0],),0)
df2_chatgpt_y = np.full((df2.shape[0],),1)

df3_human_y = np.full((df3.shape[0],),0)
df3_chatgpt_y = np.full((df3.shape[0],),1)

df4_human_y = np.full((df4.shape[0],),0)
df4_chatgpt_y = np.full((df4.shape[0],),1)

df5_human_y = np.full((df5.shape[0],),0)
df5_chatgpt_y = np.full((df5.shape[0],),1)


#x 데이터 저장
df1_human_x = df1['human_answers']
df1_chatgpt_x = df1['chatgpt_answers']

df2_human_x = df2['human_answers']
df2_chatgpt_x = df2['chatgpt_answers']

df3_human_x = df3['human_answers']
df3_chatgpt_x = df3['chatgpt_answers']

df4_human_x = df4['human_answers']
df4_chatgpt_x = df4['chatgpt_answers']

df5_human_x = df5['human_answers']
df5_chatgpt_x = df5['chatgpt_answers']

#x는 데이터프레임,  y는 넘파이 shape
X = pd.concat([df1_human_x, df1_chatgpt_x, df2_human_x, df2_chatgpt_x, df3_human_x, df3_chatgpt_x, df4_human_x, df4_chatgpt_x, df5_human_x, df5_chatgpt_x], axis = 0)
y = np.concatenate((df1_human_y, df1_chatgpt_y, df2_human_y, df2_chatgpt_y, df3_human_y, df3_chatgpt_y, df4_human_y, df4_chatgpt_y, df5_human_y, df5_chatgpt_y))

# %%
#index 열 제거 후 column명 text로 변경 & y 데이터 column명 label로 저장
X = X.reset_index()
X = X.drop('index', axis = 1)
X = X.rename(columns={0: 'text'})
X['label'] = y

# %%
#2.chatgpt vs human answer wordcloud (데이터 시각화)
from wordcloud import WordCloud
from konlpy.tag import Twitter
from collections import Counter

# %%
X_human_list =X[X['label']== 0]['text'].to_list()
X_chatgpt_list = X[X['label'] == 1]['text'].to_list()

# %%
def make_text(doc):#wordcloud를 위한 텍스트 전처리 함수
  cleaned_doc = []
  for word in doc.split(' '):
    word = word.lower()
    if word.isalpha() and len(word) > 2: #명사, 불용어 처리 없이 가장 많이 나오는 단어를 wordcloud로 시각화
      cleaned_doc.append(lemmatizer.lemmatize(word))
  return ' '.join(cleaned_doc)

cleaned_human_text = [make_text(doc) for doc in X_human_list]
cleaned_chatgpt_text = [make_text(doc) for doc in X_chatgpt_list]

# %%
#human과 chatgpt 두 category로 분류
word_list = {'human':[],'chatgpt':[]}

for text in cleaned_human_text:
    words = text.split()
    word_list['human'].extend(words)

for text in cleaned_chatgpt_text:
    words = text.split()
    word_list['chatgpt'].extend(words)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
#human text wordcloud 시각화
text = ' '.join(word_list['human'])
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(text)
plt.figure(figsize=(4, 4), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.title("human text WordCloud")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
#chatgpt text wordcloud 시각화
text = ' '.join(word_list['chatgpt'])
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(text)

plt.figure(figsize=(4, 4), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.title("chatgpt text WordCloud")
plt.show()

# %%
#3.최다 빈출 단어 그래프 시각화
human_join = " ".join(word_list['human'])
chatgpt_join = " ".join(word_list['chatgpt'])

# %%
import nltk
# make noun frequency graph per religion
def make_top_word_graph( result, top ):
    tokens = result.split(" ") # 문자열을 공백 기준으로 구분
    text = nltk.Text(tokens) # nltk 
    topWord = text.vocab().most_common(top) # top n word 
    count = 30 # top word on graph
    xlist = [a[0] for a in topWord[:count ]]
    ylist = [a[1] for a in topWord[:count ]]
    
    plt.figure(0)
  
    plt.xlabel('Word')
    plt.xticks(rotation=70) # x축 라벨 회전
    plt.ylabel('Count')
    plt.title('keyword' +' TOP '+str(count)+' WORD')
    #plt.ylim([10, 33000]) # y축 범위 (최대값을 기준으로 동일하게 설정하기 위함)
    plt.plot(xlist,ylist)

# %%
make_top_word_graph(human_join,30)

# %%
make_top_word_graph(chatgpt_join,30)

# %%
import torch
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn

import re
import random
import numpy as np
import pandas as pd

from torchtext import data
from sklearn.model_selection import train_test_split    
from copy import deepcopy

SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
config = {
        "batch_size": 64,
        "gpu_id": 0,
        "rnn": True,
        "hidden_size": 256,
        "n_layers": 2,
        "cnn": True,
        "use_batch_norm": True,
        "window_size":[3, 4, 5],
        "n_filters":[100, 100, 100],
        "word_vector_size": 300,
        "dropout":0.3,
        "n_epochs":5,
        "verbose": 1,
        "model_fn": "./model.pth",
        "max_length":256
}

# %%
from konlpy.tag import Okt
tokenizer = Okt()

# %%
def preprocess_func(sentence):
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = sentence.strip()
    sentence = sentence.strip()
    return sentence

# %%
def convert_dataset(input_data, text, label):
    list_of_example = [data.Example.fromlist(row.tolist(), fields=[('text', text), ('label', label)])  for _, row in input_data.iterrows()]
    dataset = data.Dataset(examples=list_of_example, fields=[('text', text), ('label', label)])
    return dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size = 0.3)

# %%
TEXT = data.Field(sequential=True, use_vocab=True, tokenize=tokenizer.morphs, lower=False, batch_first=True, fix_length=50)
LABEL = data.LabelField(dtype = torch.float)
BATCH_SIZE = 64

print(X_train.shape)
print(X_test.shape)

train_data = X_train.dropna() #말뭉치에서 nan 값을 제거함
test_data = X_test.dropna()


train_data['text'] = train_data['text'].apply(preprocess_func)
test_data['text']  = test_data['text'].apply(preprocess_func)

# split data
train_data, valid_data = train_test_split(train_data, test_size=0.3, random_state=32)

print(len(train_data))
print(len(valid_data))
print(len(test_data))

print(train_data.shape)
print(valid_data.shape)  
print(test_data.shape)

train_data = convert_dataset(train_data, TEXT, LABEL)
valid_data = convert_dataset(valid_data, TEXT, LABEL)
test_data  = convert_dataset(test_data, TEXT, LABEL)


print(f'Number of training examples   : {len(train_data)}')
print(f'Number of validation examples : {len(valid_data)}')
print(f'Number of testing examples    : {len(test_data)}')


MAX_VOCAB_SIZE = 20000

# 단어 사전 생성
TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

print(f"Unique tokens in TEXT vocabulary : {len(TEXT.vocab)}")
print(f"Unique tokens in LABEL vocabulary: {len(LABEL.vocab)}")

train_loader, valid_loader, test_loader = data.Iterator.splits(
  (train_data, valid_data, test_data),
  batch_size = BATCH_SIZE,
  sort = False,
  device = device)

print('Number of minibatch for training dataset   : {}'.format(len(train_loader)))
print('Number of minibatch for validation dataset : {}'.format(len(valid_loader)))
print('Number of minibatch for testing dataset    : {}'.format(len(test_loader)))
# Out:
# (34050, 2)
# (14594, 2)
# 23835
# 10215
# 14594
# (23835, 2)
# (10215, 2)
# (14594, 2)
# Number of training examples   : 23835
# Number of validation examples : 10215
# Number of testing examples    : 14594
# Unique tokens in TEXT vocabulary : 20002
# Unique tokens in LABEL vocabulary: 2
# Number of minibatch for training dataset   : 373
# Number of minibatch for validation dataset : 160
# Number of minibatch for testing dataset    : 229

# %%
class RNNModel(nn.Module):
    
    def __init__(
        self,
        input_size,
        word_vector_size,
        hidden_size,
        n_classes,
        n_layers=4,
        dropout_p=0.4
    ):
        self.input_size = input_size
        self.word_vector_size = word_vector_size
        self.hidden_size = hidden_size
        self.n_classes = n_classes
        self.n_layers = n_layers
        self.dropout_p = dropout_p
        
        super().__init__()
        
        self.emb = nn.Embedding(input_size, word_vector_size)
        self.rnn = nn.LSTM(
            input_size=self.word_vector_size,
            hidden_size=self.hidden_size,
            num_layers=self.n_layers,
            dropout=self.dropout_p,
            batch_first=True,
            bidirectional=True
        )
        
        self.linear_layer = nn.Linear(self.hidden_size*2, self.n_classes)
        self.softmax_layer = nn.LogSoftmax(dim=-1)
        
    def forward(self, x):
        # |x| = (batch_size, length)
        x = self.emb(x)
        # |x| = (batch_size, length, word_vector_size)
        x, _ = self.rnn(x)
        # |x| = (batch_size, length, hidden_size*2)
        x = self.linear_layer(x[:,-1])
        # |x| = (batch_size, n_classes)
        y = self.softmax_layer(x)
        # |x| = (batch_size, n_classes)
        
        return y

# %%
import matplotlib.pyplot as plt
class Trainer():

  def __init__(self, model, optimizer, crit):
      self.model = model
      self.optimizer = optimizer
      self.crit = crit

      super().__init__()

  def _train(self, train_loader, config):
      self.model.train()

      total_loss = 0

      for i, (x_i, y_i) in enumerate(train_loader):
          y_hat_i = self.model(x_i)
          loss_i = self.crit(y_hat_i, y_i.squeeze().long())

          # Initialize the gradients of the model.
          self.optimizer.zero_grad()
          loss_i.backward()

          self.optimizer.step()
          
          if config['verbose'] >= 2:
              print("Train Iteration(%d/%d): loss=%.4e" % (i + 1, len(train_loader), float(loss_i)))

          # Don't forget to detach to prevent memory leak.
          total_loss += float(loss_i)

      return total_loss / len(train_loader)

  def _validate(self, valid_loader, config):
      # Turn evaluation mode on.
      self.model.eval()

      # Turn on the no_grad mode to make more efficintly.
      with torch.no_grad():
          total_loss = 0

          for i, (x_i, y_i) in enumerate(valid_loader):
              y_hat_i = self.model(x_i)
              loss_i = self.crit(y_hat_i, y_i.squeeze().long())
              
              if config['verbose'] >= 2:
                  print("Valid Iteration(%d/%d): loss=%.4e" % (i + 1, len(valid_loader), float(loss_i)))

              total_loss += float(loss_i)

          return total_loss / len(valid_loader)

  def train(self, train_loader, valid_loader, config):
      lowest_loss = np.inf
      best_model = None
      train_loss_list=[]
      valid_loss_list=[]
      for epoch_index in range(config['n_epochs']):
          train_loss = self._train(train_loader, config)
          valid_loss = self._validate(valid_loader, config)

          # You must use deep copy to take a snapshot of current best weights.
          if valid_loss <= lowest_loss:
              lowest_loss = valid_loss
              best_model = deepcopy(self.model.state_dict())
          train_loss_list.append(train_loss)
          valid_loss_list.append(valid_loss)
          print("Epoch(%d/%d): train_loss=%.4e  valid_loss=%.4e  lowest_loss=%.4e" % (
              epoch_index + 1,
              config['n_epochs'],
              train_loss,
              valid_loss,
              lowest_loss,
          ))
      # 그래프의 x축은 리스트의 인덱스로 설정
      x = range(len(train_loss_list))

      # 첫 번째 리스트에 대한 그래프 (파란색)
      plt.plot(x, train_loss_list, color='blue', label='train loss')

      # 두 번째 리스트에 대한 그래프 (빨간색)
      plt.plot(x, valid_loss_list, color='red', label='valid loss')

      # x축과 y축 라벨 설정
      plt.xlabel('epoch')
      plt.ylabel('loss Value')

      # 범례 추가
      plt.legend()

      # 그래프 보여주기
      plt.show()
      
      # Restore to best model.
      self.model.load_state_dict(best_model)
      return self.model

# %%
def main(config):
    print(TEXT.vocab.freqs.most_common(20))
    print(TEXT.vocab.itos[:10])
    print(LABEL.vocab.stoi)
    
    if config["rnn"] is False and config["cnn"] is False:
        raise Exception("you should select the rnn model or cnn model or both")

    if config["rnn"]:
        model = RNNModel(
            input_size=len(TEXT.vocab),
            word_vector_size=256,
            hidden_size=128,
            n_classes=len(LABEL.vocab),
            n_layers=2,
            dropout_p=0.3

        )
        optimizer = optim.Adam(model.parameters())
        crit = nn.NLLLoss()
        print(model)
        
        if config["gpu_id"] >= 0:
            model.cuda(config["gpu_id"])
            crit.cuda(config["gpu_id"])
        rnn_trainer = Trainer(model, optimizer, crit)

        rnn_model = rnn_trainer.train(
            train_loader,
            valid_loader,
            config
        )

    torch.save(
        {
            'rnn': rnn_model.state_dict() if config["rnn"] else None,
            'config': config,
            'vocab': TEXT.vocab,
            'classes': LABEL.vocab
        }, config["model_fn"]
    )

# %%
main(config)
# Out:
# [('the', 277352), (',', 265734), ('.', 256740), ('to', 180429), ('a', 159478), ('and', 150149), ('of', 141282), ('is', 111380), ("'", 84568), ('that', 84484), ('in', 79714), ('you', 74276), ('it', 72865), ('are', 56490), ('for', 48293), ('or', 46400), ('can', 44185), ('be', 42496), ('s', 42395), ('as', 39368)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/5): train_loss=4.0000e-01  valid_loss=3.3080e-01  lowest_loss=3.3080e-01
# Epoch(2/5): train_loss=2.3647e-01  valid_loss=4.0540e-01  lowest_loss=3.3080e-01
# Epoch(3/5): train_loss=1.8207e-01  valid_loss=1.8768e-01  lowest_loss=1.8768e-01
# Epoch(4/5): train_loss=8.7852e-02  valid_loss=1.5987e-01  lowest_loss=1.5987e-01
# Epoch(5/5): train_loss=5.9036e-02  valid_loss=1.9300e-01  lowest_loss=1.5987e-01

# %%
config["n_epochs"] = 10
main(config)
# Out:
# [('the', 277352), (',', 265734), ('.', 256740), ('to', 180429), ('a', 159478), ('and', 150149), ('of', 141282), ('is', 111380), ("'", 84568), ('that', 84484), ('in', 79714), ('you', 74276), ('it', 72865), ('are', 56490), ('for', 48293), ('or', 46400), ('can', 44185), ('be', 42496), ('s', 42395), ('as', 39368)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/10): train_loss=3.7004e-01  valid_loss=2.1774e-01  lowest_loss=2.1774e-01
# Epoch(2/10): train_loss=1.5799e-01  valid_loss=1.6199e-01  lowest_loss=1.6199e-01
# Epoch(3/10): train_loss=9.0630e-02  valid_loss=2.0677e-01  lowest_loss=1.6199e-01
# Epoch(4/10): train_loss=5.4945e-02  valid_loss=1.7347e-01  lowest_loss=1.6199e-01
# Epoch(5/10): train_loss=4.0952e-02  valid_loss=1.7634e-01  lowest_loss=1.6199e-01
# Epoch(6/10): train_loss=1.9342e-02  valid_loss=2.2143e-01  lowest_loss=1.6199e-01
# Epoch(7/10): train_loss=1.8296e-02  valid_loss=2.0741e-01  lowest_loss=1.6199e-01
# Epoch(8/10): train_loss=1.6752e-02  valid_loss=2.2218e-01  lowest_loss=1.6199e-01
# Epoch(9/10): train_loss=1.0805e-02  valid_loss=2.2289e-01  lowest_loss=1.6199e-01
# Epoch(10/10): train_loss=1.0577e-02  valid_loss=2.5080e-01  lowest_loss=1.6199e-01

# %%
config["n_epochs"] = 5
batch_size=[16,32,128]
for size in batch_size:
  config["batch_size"] = size
  main(config)
# Out:
# [('the', 277352), (',', 265734), ('.', 256740), ('to', 180429), ('a', 159478), ('and', 150149), ('of', 141282), ('is', 111380), ("'", 84568), ('that', 84484), ('in', 79714), ('you', 74276), ('it', 72865), ('are', 56490), ('for', 48293), ('or', 46400), ('can', 44185), ('be', 42496), ('s', 42395), ('as', 39368)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/5): train_loss=3.7270e-01  valid_loss=2.2340e-01  lowest_loss=2.2340e-01
# Epoch(2/5): train_loss=1.8827e-01  valid_loss=1.8717e-01  lowest_loss=1.8717e-01
# Epoch(3/5): train_loss=1.0893e-01  valid_loss=1.5179e-01  lowest_loss=1.5179e-01
# Epoch(4/5): train_loss=6.2251e-02  valid_loss=1.7457e-01  lowest_loss=1.5179e-01
# Epoch(5/5): train_loss=3.8673e-02  valid_loss=1.8665e-01  lowest_loss=1.5179e-01
# [('the', 277352), (',', 265734), ('.', 256740), ('to', 180429), ('a', 159478), ('and', 150149), ('of', 141282), ('is', 111380), ("'", 84568), ('that', 84484), ('in', 79714), ('you', 74276), ('it', 72865), ('are', 56490), ('for', 48293), ('or', 46400), ('can', 44185), ('be', 42496), ('s', 42395), ('as', 39368)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/5): train_loss=3.6897e-01  valid_loss=2.2601e-01  lowest_loss=2.2601e-01
# Epoch(2/5): train_loss=1.5987e-01  valid_loss=1.7555e-01  lowest_loss=1.7555e-01
# Epoch(3/5): train_loss=9.7791e-02  valid_loss=1.5257e-01  lowest_loss=1.5257e-01
# Epoch(4/5): train_loss=6.5412e-02  valid_loss=1.5056e-01  lowest_loss=1.5056e-01
# Epoch(5/5): train_loss=3.6463e-02  valid_loss=1.8498e-01  lowest_loss=1.5056e-01
# [('the', 277352), (',', 265734), ('.', 256740), ('to', 180429), ('a', 159478), ('and', 150149), ('of', 141282), ('is', 111380), ("'", 84568), ('that', 84484), ('in', 79714), ('you', 74276), ('it', 72865), ('are', 56490), ('for', 48293), ('or', 46400), ('can', 44185), ('be', 42496), ('s', 42395), ('as', 39368)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/5): train_loss=3.5115e-01  valid_loss=2.3106e-01  lowest_loss=2.3106e-01
# Epoch(2/5): train_loss=1.6371e-01  valid_loss=1.7545e-01  lowest_loss=1.7545e-01
# Epoch(3/5): train_loss=9.9074e-02  valid_loss=1.5794e-01  lowest_loss=1.5794e-01
# Epoch(4/5): train_loss=6.3082e-02  valid_loss=1.7047e-01  lowest_loss=1.5794e-01
# Epoch(5/5): train_loss=3.7357e-02  valid_loss=2.0702e-01  lowest_loss=1.5794e-01

# %%
config["batch_size"] = 64

# %% [markdown]
# valid_loss랑 lowest_loss 그래프 시각화 해보기

# %%
model_fn = "./model.pth"
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
def load(fn, device):
  d = torch.load(fn, map_location=device)
  
  return d['rnn'], d['config'], d['vocab'], d['classes']

# %%
def test(model, test_loader):
  model.eval()
  
  correct_cnt, total_cnt = 0, 0
  with torch.no_grad():
    for x, y in test_loader:
      x, y = x.to(device), y.to(device)
      y_hat = model(x)
      correct_cnt += (y.squeeze() == torch.argmax(y_hat, dim=-1)).sum()
      total_cnt += len(x)

    accuracy = correct_cnt / total_cnt
    print("Accuracy: %.4f" % accuracy)

# %%
model_dict, train_config, vocab, classes = load(model_fn, device)

model = RNNModel(
                input_size=len(vocab),
                word_vector_size=256,
                hidden_size=128,
                n_classes=len(classes),
                n_layers=2,
                dropout_p=0.3
        )
model.load_state_dict(model_dict)
print(model)

test(model.to(device), test_loader)
# Out:
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Accuracy: 0.9405

# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
def predict(model,sentence):
    model.eval()
    with torch.no_grad():
        sent = tokenizer.morphs(sentence)
        sent = torch.tensor([TEXT.vocab.stoi[i] for i in sent])
        sent = F.pad(sent,pad = (1,50-len(sent)-1),value = 1)
        sent = sent.unsqueeze(dim = 0) #for batch
        output = torch.argmax(model(sent), dim=-1)
        return output.item()

    
examples = [
  "Colab (short for Google Colaboratory) is a free online platform for interactive programming and collaboration that provides access to computing resources such as GPUs and TPUs.",
  "Google is a multinational technology company that provides internet-related services and products.",
  "Sungkyunkwan University is a private research university located in Seoul, South Korea.",
  "Can I use your eraser? I forgot to bring my eraser.",
  "However, the feeling that something was continuing to suppress me even though I was chatting and eating snacks with my friends and playing outside of school was not erased."
]

model = model.to('cpu')
for idx in range(len(examples)) :

    sentence = examples[idx]
    pred = predict(model,sentence)
    print("\n",sentence)
    if pred == 1 :
        print(f">>>chatgpt에 의해 작성된 text입니다.({pred : .2f})")
    else:
        print(f">>>human에 의해 작성된 text입니다.({pred : .2f})")
# Out:
#  Colab (short for Google Colaboratory) is a free online platform for interactive programming and collaboration that provides access to computing resources such as GPUs and TPUs.
# >>>chatgpt에 의해 작성된 text입니다.( 1.00)
#
#  Google is a multinational technology company that provides internet-related services and products.
# >>>chatgpt에 의해 작성된 text입니다.( 1.00)
#
#  Sungkyunkwan University is a private research university located in Seoul, South Korea.
# >>>chatgpt에 의해 작성된 text입니다.( 1.00)
#
#  Can I use your eraser? I forgot to bring my eraser.
# >>>chatgpt에 의해 작성된 text입니다.( 1.00)
#
#  However, the feeling that something was continuing to suppress me even though I was chatting and eating snacks with my friends and playing outside of school was not erased.
# >>>chatgpt에 의해 작성된 text입니다.( 1.00)

# %% [markdown]
# ###df1-3과 df4-5로 나눠서 모델 성능 비교###

# %%
import numpy as np
#각각의 라벨의 데이터프레임의 행 길이만큼의 라벨 shape 생성, y데이터 저장
df1_human_y = np.full((df1.shape[0],),0)
df1_chatgpt_y = np.full((df1.shape[0],),1)

df2_human_y = np.full((df2.shape[0],),0)
df2_chatgpt_y = np.full((df2.shape[0],),1)

df3_human_y = np.full((df3.shape[0],),0)
df3_chatgpt_y = np.full((df3.shape[0],),1)

df4_human_y = np.full((df4.shape[0],),0)
df4_chatgpt_y = np.full((df4.shape[0],),1)

df5_human_y = np.full((df5.shape[0],),0)
df5_chatgpt_y = np.full((df5.shape[0],),1)


#x 데이터 저장
df1_human_x = df1['human_answers']
df1_chatgpt_x = df1['chatgpt_answers']

df2_human_x = df2['human_answers']
df2_chatgpt_x = df2['chatgpt_answers']

df3_human_x = df3['human_answers']
df3_chatgpt_x = df3['chatgpt_answers']

df4_human_x = df4['human_answers']
df4_chatgpt_x = df4['chatgpt_answers']

df5_human_x = df5['human_answers']
df5_chatgpt_x = df5['chatgpt_answers']

#x는 데이터프레임,  y는 넘파이 shape
X_F_explain = pd.concat([df1_human_x, df1_chatgpt_x, df2_human_x, df2_chatgpt_x, df3_human_x, df3_chatgpt_x], axis = 0)
y_F_explain = np.concatenate((df1_human_y, df1_chatgpt_y, df2_human_y, df2_chatgpt_y, df3_human_y, df3_chatgpt_y))

X_T_explain = pd.concat([df4_human_x, df4_chatgpt_x, df5_human_x, df5_chatgpt_x], axis = 0)
y_T_explain = np.concatenate((df4_human_y, df4_chatgpt_y, df5_human_y, df5_chatgpt_y))

X_F_explain = X_F_explain.reset_index()
X_F_explain = X_F_explain.drop('index', axis = 1)
X_F_explain = X_F_explain.rename(columns={0: 'text'})
X_F_explain['label'] = y_F_explain

X_T_explain = X_T_explain.reset_index()
X_T_explain = X_T_explain.drop('index', axis = 1)
X_T_explain = X_T_explain.rename(columns={0: 'text'})
X_T_explain['label'] = y_T_explain

# %%
from sklearn.model_selection import train_test_split
#false explain dataset
X_F_train, X_F_test = train_test_split(X_F_explain, test_size = 0.3)

#true explain dataset
X_T_train, X_T_test = train_test_split(X_T_explain, test_size = 0.3)

# %%
TEXT = data.Field(sequential=True, use_vocab=True, tokenize=tokenizer.morphs, lower=False, batch_first=True, fix_length=50)
LABEL = data.LabelField(dtype = torch.float)
BATCH_SIZE = 64

train_data = X_F_train.dropna() #말뭉치에서 nan 값을 제거함
test_data = X_F_test.dropna()

#train_data['text'] = train_data['text'].apply(preprocess_func)
#train_data['text']  = test_data['text'].apply(preprocess_func)

# split data
train_data, valid_data = train_test_split(train_data, test_size=0.3, random_state=32)

train_data = convert_dataset(train_data, TEXT, LABEL)
valid_data = convert_dataset(valid_data, TEXT, LABEL)
test_data  = convert_dataset(test_data, TEXT, LABEL)

MAX_VOCAB_SIZE = 20000

# 단어 사전 생성
TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

train_loader, valid_loader, test_loader = data.Iterator.splits(
  (train_data, valid_data, test_data),
  batch_size = BATCH_SIZE,
  sort = False,
  device = device)

# %%
main(config)
# Out:
# [('the', 61109), (',', 55085), ('.', 50676), ('to', 40701), ('a', 36383), ('and', 34035), ('of', 31028), ('is', 22052), ('you', 21103), ('in', 17528), ('that', 14685), ('your', 14658), ('for', 13582), ('or', 12737), ("'", 11732), ('are', 11418), ('be', 11136), ('as', 10885), ('can', 10753), ('on', 9509)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/5): train_loss=4.7146e-01  valid_loss=5.4411e-01  lowest_loss=5.4411e-01
# Epoch(2/5): train_loss=2.6235e-01  valid_loss=3.6407e-01  lowest_loss=3.6407e-01
# Epoch(3/5): train_loss=1.7055e-01  valid_loss=3.4675e-01  lowest_loss=3.4675e-01
# Epoch(4/5): train_loss=1.0451e-01  valid_loss=3.1070e-01  lowest_loss=3.1070e-01
# Epoch(5/5): train_loss=9.1294e-02  valid_loss=3.8760e-01  lowest_loss=3.1070e-01

# %%
model_dict, train_config, vocab, classes = load(model_fn, device)

model = RNNModel(
                input_size=len(vocab),
                word_vector_size=256,
                hidden_size=128,
                n_classes=len(classes),
                n_layers=2,
                dropout_p=0.3
        )
model.load_state_dict(model_dict)
print("df1-3 dataset accuracy")
print(model)
test(model.to(device), test_loader)
# Out:
# df1-3 dataset accuracy
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Accuracy: 0.9102

# %%
#explain_t_data
TEXT = data.Field(sequential=True, use_vocab=True, tokenize=tokenizer.morphs, lower=False, batch_first=True, fix_length=50)
LABEL = data.LabelField(dtype = torch.float)
BATCH_SIZE = 64

train_data = X_T_train.dropna() #말뭉치에서 nan 값을 제거함
test_data = X_T_test.dropna()

#train_data['text'] = train_data['text'].apply(preprocess_func)
#test_data['text']  = test_data['text'].apply(preprocess_func)

# split data
train_data, valid_data = train_test_split(train_data, test_size=0.3, random_state=32)

train_data = convert_dataset(train_data, TEXT, LABEL)
valid_data = convert_dataset(valid_data, TEXT, LABEL)
test_data  = convert_dataset(test_data, TEXT, LABEL)

MAX_VOCAB_SIZE = 20000

# 단어 사전 생성
TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

train_loader, valid_loader, test_loader = data.Iterator.splits(
  (train_data, valid_data, test_data),
  batch_size = BATCH_SIZE,
  sort = False,
  device = device)

# %%
main(config)
# Out:
# [('the', 214678), (',', 211963), ('.', 206590), ('to', 139359), ('a', 122562), ('and', 116986), ('of', 109920), ('is', 88460), ("'", 73394), ('that', 70066), ('it', 62569), ('in', 62370), ('you', 53778), ('are', 45810), ('s', 35247), ('for', 35062), ('or', 33327), ('can', 33274), ('"', 32510), ('be', 31349)]
# ['<unk>', '<pad>', 'the', ',', '.', 'to', 'a', 'and', 'of', 'is']
# defaultdict(None, {1: 0, 0: 1})
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Epoch(1/5): train_loss=3.7549e-01  valid_loss=2.2625e-01  lowest_loss=2.2625e-01
# Epoch(2/5): train_loss=1.8605e-01  valid_loss=2.4904e-01  lowest_loss=2.2625e-01
# Epoch(3/5): train_loss=1.1574e-01  valid_loss=1.5682e-01  lowest_loss=1.5682e-01
# Epoch(4/5): train_loss=5.7036e-02  valid_loss=1.9719e-01  lowest_loss=1.5682e-01
# Epoch(5/5): train_loss=3.1470e-02  valid_loss=2.5698e-01  lowest_loss=1.5682e-01

# %%
model_dict, train_config, vocab, classes = load(model_fn, device)

model = RNNModel(
                input_size=len(vocab),
                word_vector_size=256,
                hidden_size=128,
                n_classes=len(classes),
                n_layers=2,
                dropout_p=0.3
        )
model.load_state_dict(model_dict)
print(model)

test(model.to(device), test_loader)
# Out:
# RNNModel(
#   (emb): Embedding(20002, 256)
#   (rnn): LSTM(256, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (linear_layer): Linear(in_features=256, out_features=2, bias=True)
#   (softmax_layer): LogSoftmax(dim=-1)
# )
# Accuracy: 0.9459
